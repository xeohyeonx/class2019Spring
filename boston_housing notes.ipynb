# %%
# description
# https://www.kaggle.com/c/boston-housing

# TensorFlow and tf.keras
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

#Helper libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = tensorflow.keras.datasets.boston_housing.load_data(path='boston_housing.npz')
# Out:
# ...
# 57344/57026 [==============================] - 0s 2us/step

# %% [markdown]
# 총 4개의 variable에 들어와있다 생각하면 됨. x,y_train은 말그대로 이 model을 training시키기 위한 것이고, x,y_test는 training을 통해 만들어진 model이 잘 작동하는지 확인하기 위한 것.

# %%
model = Sequential()
model.add(Dense(1, input_shape=[13]))
model.compile(optimizer='rmsprop', loss='mse')
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Mycom\Anaconda\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\Mycom\Anaconda\lib\site-packages\tensorflow\python\keras\utils\losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 14
# ...
# Total params: 14
# Trainable params: 14
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 저번시간과 달리 input은 13으로 바꿔줘야
# 그 밑의 compile은 중간의 행렬을 어떻게 잘 estimate하는지 하는 알고리즘 중 하나

# %%
model.fit(x_train, y_train, epochs=1000)
# Out:
# Epoch 1/1000
# 404/404 [==============================] - 0s 69us/sample - loss: 4094.7515
# Epoch 2/1000
# 404/404 [==============================] - 0s 69us/sample - loss: 3795.3862
# Epoch 3/1000
# 404/404 [==============================] - 0s 79us/sample - loss: 3551.1555
# Epoch 4/1000
# 404/404 [==============================] - 0s 72us/sample - loss: 3308.2782
# Epoch 5/1000
# 404/404 [==============================] - 0s 69us/sample - loss: 3083.7137
# Epoch 6/1000
# 404/404 [==============================] - 0s 74us/sample - loss: 2869.0761
# Epoch 7/1000
# 404/404 [==============================] - 0s 82us/sample - loss: 2664.7622
# Epoch 8/1000
# 404/404 [==============================] - 0s 89us/sample - loss: 2470.0441
# Epoch 9/1000
# 404/404 [==============================] - 0s 70us/sample - loss: 2279.7317
# Epoch 10/1000
# 404/404 [==============================] - 0s 74us/sample - loss: 2109.4043
# Epoch 11/1000
# ...

# %% [markdown]
# 받아온 4개의 variable중 train에 해당하는 두개를 넣어주는 것. 그러면 총 13개의 column이 xtrain에, y train에는 1개의 column
# 그러고 행렬을 estimate하는것 .
# epoch는 그걸 한번 돌리는것.
# 그걸 여러번 돌리면 loss가 점점 작아짐. 그정도 되면 뭐 나름 잘 만들어졌겠다 생각하고

# %%
model.evaluate(x_test, y_test)
# Out:
# 102/102 [==============================] - 0s 2ms/sample - loss: 29.7288
# 29.72881421855852

# %% [markdown]
# 아까 train말고 만든 test라는 애들은 train할 때 쓴 애들을 제외한 애들.
# fit = 훈련이니까 훈련용 data를 쓴거고, 그렇게 쓴 애들이 아닌 따로 20프로정도 때놓은 애들을 evaluate, 즉 test할때 씀.
# 이걸 해보면 아까 train이랑 비슷하게 잘 나오네 라는걸 볼 수 있음

# %%
print(model.input_shape)
print(model.output_shape)
# Out:
# (None, 13)
# (None, 1)

# %% [markdown]
# input에는 13, output엔 1개 나오는구나 확인하는것)

# %%
# INPUT::
# 1. crim: per capita crime rate by town.
# 2. zn: proportion of residential land zoned for lots over 25,000 sq.ft.
# 3. indus: proportion of non-retail business acres per town.
# 4. chas: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
# 5. nox: nitrogen oxides concentration (parts per 10 million).
# 6. rm: average number of rooms per dwelling.
# 7. age: proportion of owner-occupied units built prior to 1940.
# 8. dis: weighted mean of distances to five Boston employment centres.
# 9. rad: index of accessibility to radial highways.
# 10. tax: full-value property-tax rate per $10,000.
# 11. ptratio: pupil-teacher ratio by town.
# 12. black: 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town.
# 13. lstat: lower status of the population (percent).

# TARGET::
# medv: median value of owner-occupied homes in $1000s.

model.predict(np.array([0, 1, 50, 1, 0, 5, .5, 10, 1000, 100, 10, 100, 1]).reshape(1,13))

# %% [markdown]
# predict 는 실제 쓸때. 즉 실제 상품화할때 쓰는것 (fit, evaluate가 아님.) 그래서 마음대로 아무런 숫자 13개를 넣어보고 그러면 비싸게 나온네? 라는 걸 알 수 있는거
