# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import csv

# %%
html = urlopen('https://music.naver.com/home/index.nhn')
bsObject = BeautifulSoup(html, "html.parser")

# %%
bsObject
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <title>네이버 뮤직</title>
# <link href="/css/music.css?bv=20190322022158" rel="stylesheet" type="text/css"/>
# <link href="/css/music2.css?bv=20190322022158" rel="stylesheet" type="text/css"/>
# <script charset="utf-8" src="/js/pkg_jindo.all.js?bv=20190322022158" type="text/javascript"></script>
# <script charset="utf-8" src="/js/pkg_external.all.js?bv=20190322022158" type="text/javascript"></script>
# ...

# %%
artist = bsObject.find()

# %%
#rank
for n in range(0,10)
    str(n) = bsObject.find_all("td", {"class":"ranking"}).get_text().split()
    print(n)
# Out:
#   File "<ipython-input-49-8bf3ab5eca1e>", line 2
#     for n in range(0,10)
#                         ^
# SyntaxError: invalid syntax

# %%
for td in range(0,10)
    td= bsObject.find("td", {"class":"ranking"}).get_text().split()
    print(td+1)
# Out:
#   File "<ipython-input-41-cc60da56cca0>", line 1
#     for td in range(0,10)
#                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# 항목마다 개개인의 패턴은 찾을 수 있는데 이들을 한꺼번에 for loop돌리기 위해 필요한 n을 어떻게 locate해야할 지 모르겠어서 실패.

# %%
ranking = bsObject.find("td", {"class":"ranking"}).get_text().split()
print(ranking)
# Out:
# ['1']

# %%
for td in bsObject.find_all('td') :
    print(td.get_text())
# Out:
# 1
#
#
#
#
#
#
# 0변동없음
#
#
# 그건 아마 우리의 잘못은 아닐 거야
# 백예린
# Our love is great
#
# 구매
#
#
# MP3구매
# 뮤직샘
#
#
#
#
#
# 2
#
#
#
#
#
#
# 4상승
# 4
#
# 당신과는 천천히
# 장범준
# 장범준 3집
#
# 구매
#
#
# MP3구매
# 뮤직샘
#
#
#
#
#
# 3
#
#
#
#
#
#
# 0변동없음
#
#
# 달라달라
# ITZY(있지)
# IT'z Different
#
# 구매
#
#
# MP3구매
# 뮤직샘
#
#
#
#
#
# 4
#
#
#
#
#
#
# -2하락
# 2
#
# 술이 달다 (Feat. Crush)
# 에픽하이 (EPIK HIGH)
# sleepless in __________
#
# 구매
#
#
# MP3구매
# 뮤직샘
#
#
#
#
#
# 5
#
#
#
#
#
#
# -1하락
# 1
#
# 옥탑방
# 엔플라잉(N.Flying)
# FLY HIGH PROJECT #2 '옥탑방'
#
# 구매
#
#
# MP3구매
# 뮤직샘
#
#
#
#
#
# 6
#
#
#
#
#
#
# -1하락
# 1
#
# 멍청이(twit)
# 화사(Hwa Sa)
# 멍청이(twit)
#
# 구매
#
#
# MP3구매
# 뮤직샘
#
#
#
#
#
# 7
#
#
#
#
#
#
# 1상승
# 1
#
# 주저하는 연인들을 위해
# 잔나비
# 전설
#
# 구매
#
#
# MP3구매
# 뮤직샘
#
#
#
#
#
# 8
#
#
#
#
#
#
# -1하락
# 1
#
# 벌써 12시
# 청하
# 벌써 12시
#
# 구매
#
#
# MP3구매
# 뮤직샘
#
#
#
#
#
# 9
#
#
#
#
#
#
# 1상승
# 1
#
# 이 노래가 클럽에서 나온다면
# 우디 (Woody)
# 이 노래가 클럽에서 나온다면
#
# 구매
#
#
# MP3구매
# 뮤직샘
#
#
#
#
#
# 10
#
#
#
#
#
#
# 1상승
# 1
#
# 고고베베 (gogobebe)
# 마마무(Mamamoo)
# ...
