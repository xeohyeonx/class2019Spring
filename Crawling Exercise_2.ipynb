# %%
# _*_ coding: UTF-8 _*_
from urllib.request import urlopen
from bs4 import BeautifulSoup
import csv

# %%
html = urlopen('https://music.naver.com/listen/top100.nhn?domain=TOTAL_V2')
bsObject = BeautifulSoup(html, "html.parser")

# %%
bsObject
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <title>TOP 100 종합 : 네이버 뮤직</title>
# <link href="/css/music.css?bv=20190322022158" rel="stylesheet" type="text/css"/>
# <link href="/css/music2.css?bv=20190322022158" rel="stylesheet" type="text/css"/>
# <script charset="utf-8" src="/js/pkg_jindo.all.js?bv=20190322022158" type="text/javascript"></script>
# <script charset="utf-8" src="/js/pkg_external.all.js?bv=20190322022158" type="text/javascript"></script>
# ...

# %%
for n in range(0,50):
    tr = bsObject.find("span", {"class":"num"+str(n)})
    print(tr)

# %%
#title
bsObject.find("a", {"title"}).get_text()
# Out:
# '그건 아마 우리의 잘못은 아닐 거야'

# %%
#rank
for rank in bsObject.find_all("td", {"class" : "ranking"}) :
    print(rank.get_text())

# %%
# rank
for ranking in range(0,50):
    td = bsObject.find("td", {"class":"num"+str(n)})
    title = bsObject.find("a", {"title"}).get_text()
    print(n+1, title)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-5b406623a4b3> in <module>
#       2 for ranking in range(0,50):
#       3     td = bsObject.find("td", {"class":"num"+str(n)})
# ----> 4     title = bsObject.find_all("a", {"title"}).get_text()
#       5     print(n+1, title)
#
# ~\Anaconda\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1882     def __getattr__(self, key):
#    1883         raise AttributeError(
# -> 1884             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1885         )
#
# AttributeError: ResultSet object has no attribute 'get_text'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %% [markdown]
# rank를 찾을 수 있는 방법을 두 가지 생각했는데, 두번째 방법이 song title 등의 다른 항목까지 같은 for loop에 포괄할 수 있는 방법이라고 생각했는데, 아래 cell과 같이 rank와 album title이 포함되어있는 태그 사이의 간격이 너무 멀어서 그런것인지 next_sibling으로 결과가 나오지 않음. 그래서 패턴을 하나하나 찾는 방법으로 일단 원하는 결과를 얻어보려고함.

# %%
#album title
title = td.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling('img')[0].get('content')
print(title)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-e45c0e69b1e5> in <module>
#       1 #album title
# ----> 2 title = td.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling('img')[0].get('content')
#       3 print(title)
#
# AttributeError: 'NoneType' object has no attribute 'next_sibling'

# %%
#album title
for img in bsObject.find_all("img", {"alt":""}):
    print(img)

# %%
title = bsObject.find_all("td", {"class" : "name"}).get_text()
print(title)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-119-68973c4e6a25> in <module>
# ----> 1 title = bsObject.find_all("td", {"class" : "name"}).get_text()
#       2 print(title)
#
# ~\Anaconda\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1882     def __getattr__(self, key):
#    1883         raise AttributeError(
# -> 1884             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1885         )
#
# AttributeError: ResultSet object has no attribute 'get_text'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
#song title
for song in range(0,50):
    title = bsObject.find_all("td", {"class" : "name"})
    print(song.get_text())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-95523e3b54c7> in <module>
#       2 for song in range(0,50):
#       3     title = bsObject.find_all("td", {"class" : "name"})
# ----> 4     print(song.get_text())
#
# AttributeError: 'int' object has no attribute 'get_text'
